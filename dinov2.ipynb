# %% [markdown]
# This example requires the following dependencies to be installed:
# pip install lightly

# %%
# !pip install lightly
# Out:
# Requirement already satisfied: lightly in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (1.5.23)
# Requirement already satisfied: certifi>=14.05.14 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (2026.4.22)
# Collecting hydra-core>=1.0.0 (from lightly)
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly)
#   Using cached lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.18.1 in /home/tsw96d/.local/lib/python3.11/site-packages (from lightly) (1.26.4)
# Requirement already satisfied: python_dateutil>=2.5.3 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in /home/tsw96d/.local/lib/python3.11/site-packages (from lightly) (2.28.2)
# Requirement already satisfied: six>=1.10 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (4.67.3)
# Requirement already satisfied: torch in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (2.11.0)
# Requirement already satisfied: torchvision in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (0.26.0)
# Requirement already satisfied: pydantic>=1.10.5 in /home/tsw96d/.local/lib/python3.11/site-packages (from lightly) (2.9.2)
# Collecting pytorch_lightning>=1.0.4 (from lightly)
#   Using cached pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3>=1.25.3 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly) (2.7.0)
# Collecting aenum>=3.1.11 (from lightly)
#   Using cached aenum-3.1.17-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: Pillow in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from lightly_utils~=0.0.0->lightly) (12.2.0)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.0.0->lightly)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.0.0->lightly)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: packaging in /home/tsw96d/.local/lib/python3.11/site-packages (from hydra-core>=1.0.0->lightly) (24.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.0.0->lightly) (6.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tsw96d/.local/lib/python3.11/site-packages (from pydantic>=1.10.5->lightly) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/tsw96d/.local/lib/python3.11/site-packages (from pydantic>=1.10.5->lightly) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from pydantic>=1.10.5->lightly) (4.15.0)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (2026.4.0)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning>=1.0.4->lightly)
#   Using cached torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from pytorch_lightning>=1.0.4->lightly) (0.15.3)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached aiohttp-3.13.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached propcache-0.5.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly)
#   Using cached yarl-1.23.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: idna>=2.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning>=1.0.4->lightly) (3.14)
# Collecting charset-normalizer<4,>=2 (from requests>=2.27.0->lightly)
#   Downloading charset_normalizer-3.4.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting urllib3>=1.25.3 (from lightly)
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: filelock in /home/tsw96d/.local/lib/python3.11/site-packages (from torch->lightly) (3.14.0)
# Requirement already satisfied: setuptools<82 in /home/tsw96d/.local/lib/python3.11/site-packages (from torch->lightly) (60.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (3.6.1)
# Requirement already satisfied: jinja2 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from torch->lightly) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->lightly) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch->lightly) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from sympy>=1.13.3->torch->lightly) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages (from jinja2->torch->lightly) (3.0.3)
# Using cached lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Using cached aenum-3.1.17-py3-none-any.whl (165 kB)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
# Using cached aiohttp-3.13.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
# Using cached multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Using cached yarl-1.23.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (102 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
# Using cached propcache-0.5.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (58 kB)
# Downloading charset_normalizer-3.4.7-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (214 kB)
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Using cached torchmetrics-1.9.0-py3-none-any.whl (983 kB)
# Installing collected packages: antlr4-python3-runtime, aenum, urllib3, propcache, omegaconf, multidict, lightly_utils, frozenlist, charset-normalizer, attrs, aiohappyeyeballs, yarl, hydra-core, aiosignal, aiohttp, torchmetrics, pytorch_lightning
#   Attempting uninstall: urllib3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/17 [aenum]
#     Found existing installation: urllib3 2.7.0━━━━━━━━━━━━━━━━  1/17 [aenum]
#     Uninstalling urllib3-2.7.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/17 [aenum]
#       Successfully uninstalled urllib3-2.7.0━━━━━━━━━━━━━━━━━━━━━━  2/17 [urllib3]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [pytorch_lightning]pytorch_lightning]]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle 1.6.17 requires bleach, which is not installed.
# kaggle 1.6.17 requires python-slugify, which is not installed.
# Successfully installed aenum-3.1.17 aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 antlr4-python3-runtime-4.9.3 attrs-26.1.0 charset-normalizer-3.4.7 frozenlist-1.8.0 hydra-core-1.3.2 lightly_utils-0.0.2 multidict-6.7.1 omegaconf-2.3.0 propcache-0.5.2 pytorch_lightning-2.6.1 torchmetrics-1.9.0 urllib3-1.26.20 yarl-1.23.0

# %% [markdown]
# Note: The model and training settings do not follow the reference settings
# from the paper. The settings are chosen such that the example can easily be
# run on a small dataset with a single GPU.

# %%
import copy
from functools import partial

# %%
import torch
import torchvision
from timm.models.vision_transformer import vit_small_patch16_224
from torch import Tensor
from torch.nn import Module
from torch.optim import AdamW

# %%
from lightly.loss import DINOLoss, IBOTPatchLoss, KoLeoLoss
from lightly.models.modules import DINOv2ProjectionHead, MaskedVisionTransformerTIMM
from lightly.models.utils import (
    random_block_mask,
    update_drop_path_rate,
    update_momentum,
)
from lightly.transforms.dino_transform import DINOTransform
from lightly.utils.scheduler import cosine_schedule, linear_warmup_schedule

# %%
def freeze_eval_module(module: Module) -> None:
    """Freeze the parameters of a module."""
    for param in module.parameters():
        param.requires_grad = False
    module.eval()

# %%
class DINOv2Head(Module):
    def __init__(
        self, dino_head: DINOv2ProjectionHead, ibot_head: DINOv2ProjectionHead
    ) -> None:
        super().__init__()
        self.dino_head = dino_head
        self.ibot_head = ibot_head

# %%
class DINOv2(Module):
    def __init__(
        self,
        ibot_separate_head: bool = False,
    ) -> None:
        super().__init__()

        # Backbones
        vit_teacher = vit_small_patch16_224(
            pos_embed="learn",
            dynamic_img_size=True,
            init_values=1e-5,
        )
        self.teacher_backbone = MaskedVisionTransformerTIMM(
            vit=vit_teacher,
            antialias=False,
            pos_embed_initialization="skip",
        )
        self.student_backbone = copy.deepcopy(self.teacher_backbone)
        update_drop_path_rate(
            self.student_backbone.vit,
            drop_path_rate=0.1,  # we recommend using smaller rates like 0.1 for vit-s-14
            mode="uniform",
        )

        freeze_eval_module(self.teacher_backbone)

        # Heads
        dino_head = partial(
            DINOv2ProjectionHead,
            input_dim=384,
        )

        teacher_dino_head = dino_head()
        student_dino_head = dino_head()

        ibot_head = partial(
            DINOv2ProjectionHead,
            input_dim=384,
        )

        if ibot_separate_head:
            teacher_ibot_head = ibot_head()
            student_ibot_head = ibot_head()
        else:
            teacher_ibot_head = teacher_dino_head
            student_ibot_head = student_dino_head

        self.teacher_head = DINOv2Head(
            dino_head=teacher_dino_head,
            ibot_head=teacher_ibot_head,
        )
        self.student_head = DINOv2Head(
            dino_head=student_dino_head,
            ibot_head=student_ibot_head,
        )

        freeze_eval_module(self.teacher_head)

    def forward(self, x: Tensor) -> Tensor:
        return self.teacher_backbone(x)

    def forward_teacher(self, x: Tensor) -> tuple[Tensor, Tensor]:
        features = self.teacher_backbone.encode(x)
        cls_tokens = features[:, 0]
        return cls_tokens, features

    def forward_student(
        self, x: Tensor, mask: Tensor | None
    ) -> tuple[Tensor, Tensor | None]:
        features = self.student_backbone.encode(x, mask=mask)
        cls_tokens = features[:, 0]
        masked_features = None if mask is None else features[mask]
        return cls_tokens, masked_features

# %%
model = DINOv2()
# Out:
# /home/tsw96d/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
transform = DINOTransform(
    global_crop_scale=(0.32, 1),
    local_crop_scale=(0.05, 0.32),
    n_local_views=8,
)

# %%
# We ignore object detection annotations by setting target_transform to return 0.
def target_transform(t):
    return 0

# %%
device = "cuda" if torch.cuda.is_available() else "mps"
model.to(device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 2
#       1 device = "cuda" if torch.cuda.is_available() else "mps"
# ----> 2 model.to(device)
#
# File ~/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1384, in Module.to(self, *args, **kwargs)
#    1381         else:
#    1382             raise
# -> 1384 return self._apply(convert)
#
# File ~/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/modules/module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/modules/module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
#     [... skipping similar frames: Module._apply at line 934 (1 times)]
#
# File ~/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/modules/module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File ~/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/modules/module.py:965, in Module._apply(self, fn, recurse)
#     961 # Tensors stored in modules are graph leaves, and we don't want to
#     962 # track autograd history of `param_applied`, so we have to use
#     963 # `with torch.no_grad():`
#     964 with torch.no_grad():
# --> 965     param_applied = fn(param)
#     966 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     968 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/.conda/envs/lightly_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1370, in Module.to.<locals>.convert(t)
#    1363     if convert_to_format is not None and t.dim() in (4, 5):
#    1364         return t.to(
#    1365             device,
#    1366             dtype if t.is_floating_point() or t.is_complex() else None,
#    1367             non_blocking,
#    1368             memory_format=convert_to_format,
#    1369         )
# -> 1370     return t.to(
#    1371         device,
#    1372         dtype if t.is_floating_point() or t.is_complex() else None,
#    1373         non_blocking,
#    1374     )
#    1375 except NotImplementedError as e:
#    1376     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# RuntimeError: PyTorch is not linked with support for mps devices

# %%
dataset = torchvision.datasets.VOCDetection(
    "datasets/pascal_voc",
    download=True,
    transform=transform,
    target_transform=target_transform,
)
# Or create a dataset from a folder containing images or videos.
# dataset = LightlyDataset("path/to/folder")

# %%
dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=64,
    shuffle=True,
    drop_last=True,
    num_workers=8,
)

# %%
# Create the loss functions.
dino_criterion = DINOLoss()
ibot_criterion = IBOTPatchLoss()
koleo_criterion = KoLeoLoss()

# %%
# Move loss to correct device because it also contains parameters.
dino_criterion = dino_criterion.to(device)
ibot_criterion = ibot_criterion.to(device)
koleo_criterion = koleo_criterion.to(device)

# %%
optimizer = AdamW(model.parameters(), lr=0.001)

# %%
epochs = 50
num_batches = len(dataloader)
total_steps = epochs * num_batches

# %%
print("Starting Training")
for epoch in range(epochs):
    total_loss = 0
    for batch_idx, batch in enumerate(dataloader):
        views = batch[0]
        views = [view.to(device) for view in views]
        global_views = torch.cat(views[:2])
        local_views = torch.cat(views[2:])

        # Masking
        B = len(global_views)
        sequence_length = model.teacher_backbone.sequence_length
        mask = global_views.new_zeros((B, sequence_length), dtype=torch.bool)

        # Mask patches except class token.
        H, W = model.teacher_backbone.vit.patch_embed.grid_size
        assert H * W == sequence_length - 1, (
            f"Unexpected grid size: {H}x{W}, sequence_length {sequence_length}"
        )
        block_mask = random_block_mask(size=(B, H, W), device=mask.device)
        mask[:, 1:] = block_mask.flatten(start_dim=1)

        # Teacher forward
        with torch.no_grad():
            teacher_cls_token, teacher_features = model.forward_teacher(global_views)
            teacher_cls_out = model.teacher_head.dino_head.forward(teacher_cls_token)
            teacher_masked_out = model.teacher_head.ibot_head.forward(
                teacher_features[mask]
            )

        # Student forward
        (
            student_global_cls_token,
            student_global_masked_features,
        ) = model.forward_student(global_views, mask=mask)
        student_global_cls_out = model.student_head.dino_head.forward(
            student_global_cls_token
        )
        student_global_masked_out = model.student_head.ibot_head.forward(
            student_global_masked_features
        )
        student_local_cls_token, _ = model.forward_student(local_views, mask=None)
        student_local_cls_out = model.student_head.dino_head.forward(
            student_local_cls_token
        )
        student_cls_out = torch.cat([student_global_cls_out, student_local_cls_out])

        # Calculate current global step based on epoch and batch index.
        global_step = epoch * num_batches + batch_idx

        # Calculate the loss.
        teacher_temp = linear_warmup_schedule(
            step=global_step,
            warmup_steps=int(30 / epochs * total_steps),
            start_value=0.04,
            end_value=0.07,
        )
        dino_loss = dino_criterion(
            teacher_out=teacher_cls_out.chunk(2),
            student_out=student_cls_out.chunk(len(views)),
            teacher_temp=teacher_temp,
        )
        ibot_loss = ibot_criterion(
            teacher_out=teacher_masked_out,
            student_out=student_global_masked_out,
            mask=block_mask,
            teacher_temp=teacher_temp,
        )
        koleo_loss = 0.1 * sum(
            koleo_criterion(t) for t in student_global_cls_token.chunk(2)
        )
        loss = dino_loss + ibot_loss + koleo_loss

        total_loss += loss.detach()
        loss.backward()

        # Optionally zero out the learning rate of the last layer.
        if epoch < 1:
            for param_group in optimizer.param_groups:
                if "last_layer" in param_group:
                    param_group["lr"] = 0.0

        # Apply weight decay schedule.
        weight_decay = cosine_schedule(
            step=global_step,
            max_steps=total_steps,
            start_value=0.04,
            end_value=0.4,
        )

        # Update weight decay directly for all parameter groups.
        for group in optimizer.param_groups:
            if group["weight_decay"] != 0.0:
                group["weight_decay"] = weight_decay

        optimizer.step()
        optimizer.zero_grad()

        # Momentum update teacher.
        momentum = cosine_schedule(
            step=global_step,
            max_steps=total_steps,
            start_value=0.992,
            end_value=1.0,
        )
        update_momentum(model.student_backbone, model.teacher_backbone, m=momentum)
        update_momentum(model.student_head, model.teacher_head, m=momentum)

    avg_loss = total_loss / len(dataloader)
    print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
